# %%
#import the pandas libaray
import pandas as pd

# %%
# to delete the dataframe
del df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # to delete the dataframe
# ----> 2 del df
#
# NameError: name 'df' is not defined

# %%
#read the cvs file (Comma-Separated Values)
df=pd.read_csv('shopping_trends.csv')
print("The dataframe is ",df)
# Out:
# The dataframe is        Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#let the number of columns from the above dataset
cols=df.shape[1]
print ("the columns are ",cols)
# to get the no of rows
row=df.shape[0]
print("thw rows are ",row);
#to entries from the dataframe
entries=df.shape
print("the entries are ",entries)
# Out:
# the columns are  19
# thw rows are  3900
# the entries are  (3900, 19)

# %%
#to get the columns name
col_name=df.columns
#print(f"The column names are: {col_name}")
#the above col_name is array formate
for x in col_name:
    print(x)

#df[x] -->display each column
# Out:
# Customer ID
# Age
# Gender
# Item Purchased
# Category
# Purchase Amount (USD)
# Location
# Size
# Color
# Season
# Review Rating
# Subscription Status
# Payment Method
# Shipping Type
# Discount Applied
# Promo Code Used
# Previous Purchases
# Preferred Payment Method
# Frequency of Purchases

# %%
#Let know the datatype of each column
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %% [markdown]
# ## how we can can group customer by age
# ## -The first step is to divide customer into different age groups.
# This help us better understand how different age demographics are interacting with our products.
# we'll create bins, like 18-25,'26-35','36-45' and 46+
# This will make it easier to visualize and analyze the data
# we can then use a bar plot to show the distribution of customers across these ag##  g
#
# #for this pd.cut(df,bins='',label='') methodroups

# %%
df.head(13)
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male         Blouse     Clothing
# 1             2   19   Male        Sweater     Clothing
# 2             3   50   Male          Jeans     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male         Blouse     Clothing
# 5             6   46   Male       Sneakers     Footwear
# 6             7   63   Male          Shirt     Clothing
# 7             8   27   Male         Shorts     Clothing
# 8             9   26   Male           Coat    Outerwear
# 9            10   57   Male        Handbag  Accessories
# 10           11   53   Male          Shoes     Footwear
# 11           12   30   Male         Shorts     Clothing
# 12           13   61   Male           Coat    Outerwear
#
#     Purchase Amount (USD)       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# ...

# %%
#binning technique
#uisng the pd.cut(df[x],bins='',labels='')
#let create bins and labels (tags)
Bins = [0, 18, 26, 36, 46, float('inf')]
Tags=['under18','18-25','26-35','36-45','46+']
#using cut()
df['GroupedAge']=pd.cut(df['Age'],bins=Bins,labels=Tags)
print(df)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
'''This will make it easier to visualize and analyze the data 
we can then use a bar plot to show the distribution of customers across these age groups'''

#using matplotlib,seaborn
import matplotlib.pyplot as mplt
import seaborn as sns

# %%
# #count of groupedAge
# groupedAge=df['GroupedAge'].value_counts();
# groupedAge
# groupedAge.index

# #age
# age_group=df['GroupedAge'].values_counts().sort_index()
# print(age_group.index)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the number of customers in each age group
age_group_counts = df['GroupedAge'].value_counts().sort_index()
print(age_group_counts)

plt.figure(figsize=(10, 6))
sns.barplot(x=age_group_counts.index, y=age_group_counts.values)

# Add labels and title
plt.xlabel('Age Groups')
plt.ylabel('Number of Customers')
plt.title('Distribution of Customers Across Age Groups')


# Show the plot
plt.show()



#bar plot
# Create the bar plot
mplt.figure(figsize=(10, 6))
groupedAge.plot(kind='bar', color=['pink','blue'])
mplt.title("The distribution of grouped Age of Customer")
# label the x and y axis
mplt.xlabel('Grouped Age')
mplt.ylabel('no of customer')
mplt.show()
# Out:
# GroupedAge
# under18      69
# 18-25       571
# 26-35       747
# 36-45       731
# 46+        1782
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 25
#      22 #bar plot
#      23 # Create the bar plot
#      24 mplt.figure(figsize=(10, 6))
# ---> 25 groupedAge.plot(kind='bar', color=['pink','blue'])
#      26 mplt.title("The distribution of grouped Age of Customer")
#      27 # label the x and y axis
#
# NameError: name 'groupedAge' is not defined

# %%
mplt.figure(figsize=(15, 7))
sns.barplot(x=groupedAge.index, y=groupedAge.values)
# label the x and y axis
mplt.xlabel('Grouped Age')
mplt.ylabel('no of customer')
mplt.show()

# %% [markdown]
# ## could you explain how we can handle the categorical variables 'gender' and 'repeatPurchase'
# For categorical variable like 'gender' and 'repeatpurchase', we'll use a technique that cover these categories into numerical value
# This help our analysis since many statistical tool require numerical input.

# %%
last2nd_column = df.iloc[:, -2]
print(last2nd_column)
# Out:
# 0       Fortnightly
# 1       Fortnightly
# 2            Weekly
# 3            Weekly
# 4          Annually
#            ...
# 3895         Weekly
# 3896      Bi-Weekly
# 3897      Quarterly
# 3898         Weekly
# 3899      Quarterly
# Name: Frequency of Purchases, Length: 3900, dtype: object

# %%
df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# ...

# %%
#Mapping technique
#converting categorical /ordinal data --> numerical data
maping_dict={"Annually":1,"Weekly":2,"Bi-Weekly":3,"Quarterly":4,"Fortnightly": 3};
print(maping_dict['Annually'])
#  'Frequency of Purchases' column lets make into numerical
df['Frequency of Purchases_Mapped'] = df['Frequency of Purchases'].map(maping_dict)
print(df)
# Out:
# 1
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# ...

# %% [markdown]
# -once we’ve we can move on to exploring the relationship between these variables.
# could you elaborate on how we can explore the relationship between the numeric attribute 'age' and 'productRating'
# to understand how 'age' and 'productRating'  are related , we'll calculate something called a covarriance matrix
# this matrix gives us an idas of hwe the two attributes change together?

# %%
df[['Age','Review Rating']]
# Out:
#       Age  Review Rating
# 0      55            3.1
# 1      19            3.1
# 2      50            3.1
# 3      21            3.5
# 4      45            2.7
# ...   ...            ...
# 3895   40            4.2
# 3896   52            4.5
# 3897   46            2.9
# 3898   44            3.8
# 3899   52            3.1
#
# [3900 rows x 2 columns]

# %% [markdown]
# #using the cov method
# #The covariance matrix will help us understand how the two attributes change together
# Values close to 1 indicate a strong positive correlation.
# Values close to -1 indicate a strong negative correlation.
# Values close to 0 indicate no correlation.

# %%
#The range for covariance is from negative infinity to positive infinity.
matrix=df[['Age','Review Rating']]
cov_matrix=matrix.cov()
print(cov_matrix)
# Out:
#                       Age  Review Rating
# Age            231.270767      -0.239071
# Review Rating   -0.239071       0.512975

# %% [markdown]
# after we've calculated the covariance matrix we can visualize it using a heat map.
# The heat map will help us identify patterns or trends between these attributes.

# %%
# create the heatmap
mplt.figure(figsize=(8, 6))
sns.heatmap(cov_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
mplt.title('covariance matrix')
mplt.show()

# %%
#Correlation values range from -1 to 1
corr_matrix=matrix.corr();
print(corr_matrix)
# Out:
#                     Age  Review Rating
# Age            1.000000      -0.021949
# Review Rating -0.021949       1.000000

# %%
# create the heatmap
mplt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
mplt.title('covariance matrix')
mplt.show()

# %%
df.dtypes
# Out:
# Customer ID                         int64
# Age                                 int64
# Gender                             object
# Item Purchased                     object
# Category                           object
# Purchase Amount (USD)               int64
# Location                           object
# Size                               object
# Color                              object
# Season                             object
# Review Rating                     float64
# Subscription Status                object
# Payment Method                     object
# Shipping Type                      object
# Discount Applied                   object
# Promo Code Used                    object
# Previous Purchases                  int64
# Preferred Payment Method           object
# Frequency of Purchases             object
# GroupedAge                       category
# Frequency of Purchases_Mapped     float64
# dtype: object

# %% [markdown]
# let's discuss the association between 'gender' and 'repeatpurchase'.
# To determine if there's a significant connection between 'gender; and 'repeatpurchase' we'll use a statistical test.
# This test will help us figure out if the two variables are independent or it there's a relationship
# once we've done the test .we can present the result,including the statistical values and perhaps a stacked bar plot to visually demonstrate the association.

# %%
df[['Gender','Frequency of Purchases']]
# Out:
#       Gender Frequency of Purchases
# 0       Male            Fortnightly
# 1       Male            Fortnightly
# 2       Male                 Weekly
# 3       Male                 Weekly
# 4       Male               Annually
# ...      ...                    ...
# 3895  Female                 Weekly
# 3896  Female              Bi-Weekly
# 3897  Female              Quarterly
# 3898  Female                 Weekly
# 3899  Female              Quarterly
#
# [3900 rows x 2 columns]

# %% [markdown]
# ## since gender,Frequency of Purchases are the categorical data we can use chi-square test

# %%
#using crosstab,using scipy.stats import chi2_contingency
from scipy.stats import chi2_contingency
table = pd.crosstab(df['Gender'], df['Frequency of Purchases'])
print(table)
# Out:
# Frequency of Purchases  Annually  Bi-Weekly  Every 3 Months  Fortnightly  \
# Gender
# Female                       185        188             186          163
# Male                         387        359             398          379
#
# Frequency of Purchases  Monthly  Quarterly  Weekly
# Gender
# Female                      185        169     172
# Male                        368        394     367

# %%
chi2,pvalue,dof,excepted=chi2_contingency(table)
print(f"The value which describe diff blw Ob and Ex Freq :{chi2}")
print(f"The P value helps determine the statistical significance of the observed association :{pvalue}")
print(f"Choosing of degree of freedom :{dof}")
print(f"Each cell excepted Freq:{excepted}")
# Out:
# The value which describe diff blw Ob and Ex Freq :3.928008815312865
# The P value helps determine the statistical significance of the observed association :0.6864183021067272
# Choosing of degree of freedom :6
# Each cell excepted Freq:[[183.04 175.04 186.88 173.44 176.96 180.16 172.48]
#  [388.96 371.96 397.12 368.56 376.04 382.84 366.52]]

# %% [markdown]
# ## since p>0.05 accept the null hypothesis
# ## there is no statistically significant evidence to suggest a relationship between 'Gender' and 'Frequency of Purchases'

# %% [markdown]
#  perhaps a stacked bar plot to visually demonstrate the association

# %%
# Plot stacked bar plot
table.plot(kind='bar', stacked=True)
mplt.title('Frequency of Purchases by Gender')
mplt.xlabel('Gender')
mplt.ylabel('Count')
mplt.legend(title='Frequency of Purchases')
mplt.show()

# %% [markdown]
# how can we compare the 'productRating' for customer who made repeat purchase versus those who didn't?
# To compare the 'productRating' between these two groups ,we'll use a statistical test called an independent t-test
# This test help us determine if there's a significant difference in the mean 'productingRating' scores.
# we'll state our hypotheses,calculate the test statistic and p-value,interpret the result.
# Additionally we can visualize the difference using box plts for both groups.

# %%
df.dtypes
# Out:
# Customer ID                         int64
# Age                                 int64
# Gender                             object
# Item Purchased                     object
# Category                           object
# Purchase Amount (USD)               int64
# Location                           object
# Size                               object
# Color                              object
# Season                             object
# Review Rating                     float64
# Subscription Status                object
# Payment Method                     object
# Shipping Type                      object
# Discount Applied                   object
# Promo Code Used                    object
# Previous Purchases                  int64
# Preferred Payment Method           object
# Frequency of Purchases             object
# GroupedAge                       category
# Frequency of Purchases_Mapped     float64
# dtype: object

# %%
data=df[['Review Rating','Frequency of Purchases_Mapped']]
data.tail(10)
# Out:
#       Review Rating  Frequency of Purchases_Mapped
# 3890            2.6                            1.0
# 3891            4.7                            4.0
# 3892            3.5                            3.0
# 3893            3.3                            3.0
# 3894            3.9                            NaN
# 3895            4.2                            2.0
# 3896            4.5                            3.0
# 3897            2.9                            4.0
# 3898            3.8                            2.0
# 3899            3.1                            4.0

# %% [markdown]
# ## so t-test is used for both to the significant blw the two mean grouped ,for the chi-square we will use for categorical just to know  the significant!

# %%
from scipy.stats import ttest_ind

# %%
repeat_purchase_ratings = df[df['Frequency of Purchases_Mapped'] == 1]['Review Rating']
non_repeat_purchase_ratings = df[df['Frequency of Purchases_Mapped'] == 0]['Review Rating']
print(repeat_purchase_ratings)
print(non_repeat_purchase_ratings)
# Out:
# 4       2.7
# 8       2.6
# 22      3.2
# 25      3.6
# 26      3.6
#        ...
# 3875    3.3
# 3876    2.6
# 3878    3.4
# 3889    3.5
# 3890    2.6
# Name: Review Rating, Length: 572, dtype: float64
# Series([], Name: Review Rating, dtype: float64)

# %%
t_stat, p_value = ttest_ind(repeat_purchase_ratings, non_repeat_purchase_ratings)

print(f"T-Statistic: {t_stat}")
print(f"P-Value: {p_value}")
# Out:
# T-Statistic: nan
# P-Value: nan

# %%
print(repeat_purchase_ratings)
# Out:
# 4       2.7
# 8       2.6
# 22      3.2
# 25      3.6
# 26      3.6
#        ...
# 3875    3.3
# 3876    2.6
# 3878    3.4
# 3889    3.5
# 3890    2.6
# Name: Review Rating, Length: 572, dtype: float64

# %%
print(non_repeat_purchase_ratings)
# Out:
# Series([], Name: Review Rating, dtype: float64)

# %%
df_clean = df.dropna(subset=['Frequency of Purchases_Mapped'])

print(df_clean)

group1_ratings = df_clean[df_clean['Frequency of Purchases_Mapped'] == 0]['Review Rating']
group2_ratings = df_clean[df_clean['Frequency of Purchases_Mapped'] == 1]['Review Rating']

t_stat, p_value = ttest_ind(group1_ratings, group2_ratings, equal_var=False)  

print(f"T-Statistic: {t_stat}")
print(f"P-Value: {p_value}") #p>0.05 accept the ho mean frequency purchased independent of rating no significant
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# ...

# %%
mplt.figure(figsize=(10, 6))
sns.boxplot(x='Frequency of Purchases_Mapped', y='Review Rating', data=df_clean)
mplt.title(' Review Ratings by Frequency of Purchases')
mplt.xlabel('Frequency of Purchases')
mplt.ylabel('Review Rating')
mplt.show()

# %%
df['Frequency of Purchases_Mapped'].isna().sum()
df['Frequency of Purchases_Mapped'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Name: Frequency of Purchases_Mapped, Length: 3900, dtype: bool

# %%
missing_rows = df[df['Frequency of Purchases_Mapped'].isna()]
print("Rows with missing values in 'Frequency of Purchases_Mapped':")
print(missing_rows)
# Out:
# Rows with missing values in 'Frequency of Purchases_Mapped':
#       Customer ID  Age  Gender Item Purchased     Category  \
# 15             16   64    Male          Skirt     Clothing
# 20             21   21    Male          Pants     Clothing
# 27             28   56    Male         Shorts     Clothing
# 28             29   54    Male        Handbag  Accessories
# 30             31   57    Male        Jewelry  Accessories
# ...           ...  ...     ...            ...          ...
# 3871         3872   55  Female        T-shirt     Clothing
# 3872         3873   41  Female         Jacket    Outerwear
# 3877         3878   28  Female         Hoodie     Clothing
# 3880         3881   42  Female          Shirt     Clothing
# 3894         3895   66  Female          Skirt     Clothing
#
#       Purchase Amount (USD)        Location Size  Color  Season  ...  \
# 15                       81    Rhode Island    M   Teal  Winter  ...
# ...

# %%
df_clean = df.dropna(subset=['Frequency of Purchases_Mapped'])
df_clean.head(17)
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male         Blouse     Clothing
# 1             2   19   Male        Sweater     Clothing
# 2             3   50   Male          Jeans     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male         Blouse     Clothing
# 5             6   46   Male       Sneakers     Footwear
# 6             7   63   Male          Shirt     Clothing
# 7             8   27   Male         Shorts     Clothing
# 8             9   26   Male           Coat    Outerwear
# 9            10   57   Male        Handbag  Accessories
# 10           11   53   Male          Shoes     Footwear
# 11           12   30   Male         Shorts     Clothing
# 12           13   61   Male           Coat    Outerwear
# 13           14   65   Male          Dress     Clothing
# 14           15   64   Male           Coat    Outerwear
# 16           17   25   Male     Sunglasses  Accessories
# ...
